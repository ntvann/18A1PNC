# %%
import numpy as np
import pandas as pd 
np.random.seed(100)
ser = pd.Series(np.random.randint(1, 10, 35))
array = ser.values

df_reshaped = pd.DataFrame(array.reshape(7, 5))

print("Series gốc (35 phần tử):")
print(ser.head(7))
print("\n" + "-"*20 + "\n")
print("DataFrame sau khi định hình lại (7 hàng, 5 cột):")
print(df_reshaped)
# Out:
# Series gốc (35 phần tử):
# 0    9
# 1    9
# 2    4
# 3    8
# 4    8
# 5    1
# 6    5
# dtype: int32
#
# --------------------
#
# DataFrame sau khi định hình lại (7 hàng, 5 cột):
#    0  1  2  3  4
# 0  9  9  4  8  8
# 1  1  5  3  6  3
# 2  3  3  2  1  9
# 3  5  1  7  3  5
# 4  2  6  4  5  5
# 5  4  8  2  2  8
# 6  8  1  3  4  3

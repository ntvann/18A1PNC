# %%
import numpy as np 
import pandas as pd 
np.random.seed(100)
ser = pd.Series(np.random.randint(1, 5, size=12))
print("Series ban đầu:")
print(ser)
print("\n" + "-"*20 + "\n")

top2_values = ser.value_counts().nlargest(2).index.tolist()

ser_new = ser.copy()

ser_new[~ser_new.isin(top2_values)] = 'Other'

print(f"Top 2 giá trị tần suất cao nhất: {top2_values}")
print("\nSeries sau khi thay thế:")
print(ser_new)
# Out:
# Series ban đầu:
# 0     1
# 1     1
# 2     4
# 3     4
# 4     4
# 5     4
# 6     1
# 7     3
# 8     3
# 9     1
# 10    3
# 11    2
# dtype: int32
#
# --------------------
#
# Top 2 giá trị tần suất cao nhất: [1, 4]
#
# Series sau khi thay thế:
# 0         1
# 1         1
# 2         4
# 3         4
# 4         4
# 5         4
# 6         1
# 7     Other
# 8     Other
# 9         1
# 10    Other
# 11    Other
# dtype: object
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_19560\1923833206.py:13: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Other' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   ser_new[~ser_new.isin(top2_values)] = 'Other'

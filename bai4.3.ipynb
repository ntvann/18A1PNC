# %%
import pandas as pd
import numpy as np
ser1 = pd.Series(list('abcdefghijklmnopqrstuvwxyz'))
ser2 = pd.Series(np.arange(26))
df_combined = pd.concat([ser1, ser2], axis=1)
df_combined.columns = ['Col1_Chars', 'Col2_Nums']

print("Series ser1:")
print(ser1.head())
print("\nSeries ser2:")
print(ser2.head())
print("\n" + "="*30 + "\n")
print("DataFrame sau khi kết nối:")
print(df_combined.head())
# Out:
# Series ser1:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# dtype: object
#
# Series ser2:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64
#
# ==============================
#
# DataFrame sau khi kết nối:
#   Col1_Chars  Col2_Nums
# 0          a          0
# 1          b          1
# 2          c          2
# 3          d          3
# 4          e          4

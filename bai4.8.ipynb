# %%
import numpy as np 
import pandas as pd
np.random.seed(100)
ser = pd.Series(np.random.random(20)) 
deciles_num = pd.qcut(ser, q=10, labels=False)

decile_labels = [f'P{i*10}' for i in range(1, 11)]

ser_deciles = pd.qcut(ser, q=10, labels=decile_labels)

print("Series gốc (5 phần tử đầu):")
print(ser.head())
print("\n" + "-"*20 + "\n")
print("Series sau khi thay thế bằng tên phân vị (5 phần tử đầu):")
print(ser_deciles.head())

print("\nSố lượng phần tử trong mỗi phân vị:")
print(ser_deciles.value_counts())
# Out:
# Series gốc (5 phần tử đầu):
# 0    0.543405
# 1    0.278369
# 2    0.424518
# 3    0.844776
# 4    0.004719
# dtype: float64
#
# --------------------
#
# Series sau khi thay thế bằng tên phân vị (5 phần tử đầu):
# 0    P60
# 1    P50
# 2    P60
# 3    P90
# 4    P10
# dtype: category
# Categories (10, object): ['P10' < 'P20' < 'P30' < 'P40' ... 'P70' < 'P80' < 'P90' < 'P100']
#
# Số lượng phần tử trong mỗi phân vị:
# P10     2
# P20     2
# P30     2
# P40     2
# P50     2
# P60     2
# P70     2
# P80     2
# P90     2
# P100    2
# Name: count, dtype: int64

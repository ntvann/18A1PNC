# %%
import numpy as np 
import pandas as pd 
ser = pd.Series(list('abcdefghijklmnopqrstuvwxyz'))
pos = [0, 4, 8, 14, 20] 
elements_at_pos = ser.iloc[pos]

print("Series gốc (5 phần tử đầu):")
print(ser.head())
print(f"Các vị trí cần lấy: {pos}")
print("\n" + "-"*20 + "\n")
print("Các phần tử tại các vị trí đã cho:")
print(elements_at_pos)
# Out:
# Series gốc (5 phần tử đầu):
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# dtype: object
# Các vị trí cần lấy: [0, 4, 8, 14, 20]
#
# --------------------
#
# Các phần tử tại các vị trí đã cho:
# 0     a
# 4     e
# 8     i
# 14    o
# 20    u
# dtype: object

# %%
import numpy as np 
import pandas as pd 
np.random.seed(100)
ser = pd.Series(np.random.randint(1, 8, size=30))

ser = pd.Series(np.random.randint(1, 8, size=30))
print("Series ban đầu:")
print(ser.head(10))
print("\n" + "-"*20 + "\n")

frequency = ser.value_counts()

print("2. Tần số xuất hiện của mỗi giá trị duy nhất (dùng .value_counts()):")
print(frequency)
# Out:
# Series ban đầu:
# 0    6
# 1    6
# 2    4
# 3    5
# 4    5
# 5    4
# 6    4
# 7    4
# 8    2
# 9    2
# dtype: int32
#
# --------------------
#
# 2. Tần số xuất hiện của mỗi giá trị duy nhất (dùng .value_counts()):
# 4    7
# 6    5
# 2    5
# 7    5
# 5    3
# 1    3
# 3    2
# Name: count, dtype: int64
